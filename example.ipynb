# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wavelet import *
# %matplotlib inline

# %%
t = np.linspace(0,10,1000)
Y = np.array([np.sin(2*np.pi*2*t),np.sin(2*np.pi*2*t)]).T
print(np.shape(Y))
analysis = FrequencyAnalysis(n_freqs=10000, fsample=100, fmin=0.5, fmax=10)(Y)
plt.plot(analysis['frequency'][1])
plt.plot(analysis['frequency'][0])
plt.show()
# Out:
# (1000, 2)

# %%
pa = PhaseAna()
phase = pa.getPhase(Y[:,0])
plt.plot(Y[:,0])
plt.plot(phase)
plt.show()

# %%
df=pd.read_csv("Filename_selection_split#5_0.txt",sep="\t",index_col='Time')
df1=df.iloc[:,:3]
# Label the columns as 'x', 'y', and 'z'
df1.columns = ['x', 'y', 'z']

# %%
z = df1['z']
print(len(z))
Z = z[51000:51200]
print(Z)
# Out:
# 84903
# Time
# 04:03:15.720    0.263916
# 04:03:15.759    0.104980
# 04:03:15.800    1.862790
# 04:03:15.840    0.548828
# 04:03:15.880   -0.358887
#                   ...
# 04:03:23.519    0.155762
# 04:03:23.560    0.437988
# 04:03:23.600    1.406980
# 04:03:23.640    1.968990
# 04:03:23.680    0.655762
# Name: z, Length: 200, dtype: float64

# %%
analysis = FrequencyAnalysis(n_freqs=10000, fsample=25, fmin=0.5, fmax=10)(Z)
plt.plot(analysis['frequency'][1])
plt.plot(analysis['frequency'][0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 analysis = FrequencyAnalysis(n_freqs=10000, fsample=25, fmin=0.5, fmax=10)(Z)
#       2 plt.plot(analysis['frequency'][1])
#       3 plt.plot(analysis['frequency'][0])
#
# File ~\Desktop\Github\waveanalysis\wavelet.py:276, in FrequencyAnalysis.__call__(self, X, n_jobs)
#     274 def __call__(self, X, n_jobs=1):
#     275     if X.ndim is not 2:
# --> 276         raise ValueError('X.ndim must be 2')
#     277     if X.shape[1] > 2:
#     278         raise ValueError('n_features must be 2')
#
# ValueError: X.ndim must be 2
